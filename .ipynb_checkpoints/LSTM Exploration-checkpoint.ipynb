# %%
import pandas as pd

# %%
condensed_df = pd.read_csv('src/data/condensed_data.csv')

# %%
condensed_df
# Out:
#        playerID  year1_2B  year1_3B  year1_AVG  year1_BB  year1_CS  year1_G  \
# 0     aaronha01        27         6   0.279915        28       2.0      122
# 1     abbotku01        17         3   0.249275        16       0.0      101
# 2     abreubo01        10         2   0.250000        21       2.0       59
# 3     adairje01        21         1   0.264249        35       2.0      133
# 4     adamsbo03        13         3   0.244373        18       0.0       94
# 5     adamssp01        12         0   0.289389        26      19.0       95
# 6     adcocjo01        16         1   0.293011        24       0.0      102
# 7      ageeto01        27         8   0.273450        41      18.0      160
# 8     ainsmed01         1         2   0.192308         6       0.0       33
# 9     aldremi01        18         3   0.250000        33       3.0       84
# 10    alfoned01        13         5   0.277612        12       1.0      101
# ...
